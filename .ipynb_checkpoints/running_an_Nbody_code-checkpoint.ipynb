# %% [markdown]
# How to run a simple N-body code
# ====================
#
# Here we will generate initial conditions for an N-body code, run a small simulation and analyse the results. This analysis is performed on a 100 star cluster in a 1 pc virial-radius King model. Stellar masses are taken randomly from a Salpeter distribution.
# Stellar evolution is ignored in this simulation.
#
# For reference you can read chapter 2 of Portegies Zwart & McMillan 2018 (2018araa.book.....P).
#
# With this tutorial you will learn
# - how to generate initial conditions (mass function, King-model)
# - to initialize a gravitational N-body code
# - channels and intra-code data transfer
# - detecting binaries
# - plotting results
# - making cumulative distributions

# %%
# %matplotlib inline
import numpy
from matplotlib import pyplot
from amuse.units import units

# %% [markdown]
# We start by setting-up a simulation by specifying a stellar mass distribution

# %%
n_stars = 100
alpha_IMF = -2.35

from amuse.lab import new_powerlaw_mass_distribution
m_stars = new_powerlaw_mass_distribution(n_stars, 0.1|units.MSun, 
                                        100|units.MSun, alpha_IMF)

# %% [markdown]
# Now check to see if this indeed gives one the expected mass function by plotting the cumulative distribution against a theoretical distribution.

# %%
def plot_cdf(m, alpha_IMF=-2.35):
    m = sorted(m.value_in(units.MSun))
    fm = numpy.array([0])
    for mi in m:
        fm = numpy.append(fm, fm[-1] + mi)
    fm /= max(fm)
    from amuse.plot import plot
    pyplot.plot(m, fm[:len(m)], lw=4, ls="-")
    x = 10**numpy.arange(-1.0, 1.0, 1./len(m))
    y = x**(alpha_IMF+2)
    fy = numpy.array([0])
    for yi in y:
        fy = numpy.append(fy, fy[-1] + yi)    
    fy /= max(fy)
    pyplot.plot(x, fy[:len(x)], lw=2, ls=":")
    pyplot.semilogx()
    pyplot.show()
plot_cdf(m_stars)

# %% [markdown]
# ### Question:
# Can you explain why the dotted curve does not overplot with the solid curve?
#
# Now we can initialize the cluster size and declare the converter.
#
# ### Converter
# N-body codes operate using special dimensionless N-body units (where the gravitational constant is set to unity). In order to make the code understand SI units, we must pass it a unit converter. This contains two quantities in the relevant unit system, from which AMUSE derives the proper unit conversion. Best practice is to keep those quantities on the order of the system's scale (e.g. the total mass and the radius of the outermost planet in a planetary system) to ensure numerical stability.
#
# Also see the documentation on the importance of [converters](https://amuse.readthedocs.io/en/latest/reference/quantities_and_units.html?highlight=generic%20units#module-amuse.units.generic_unit_system) in AMUSE.

# %%
r_cluster = 1.0 | units.parsec
from amuse.units import nbody_system
converter=nbody_system.nbody_to_si(m_stars.sum(),r_cluster)
from amuse.ic.kingmodel import new_king_model
W0 = 3.0
bodies=new_king_model(n_stars, W0, convert_nbody=converter)
bodies.mass = m_stars.in_(units.MSun)
bodies.scale_to_standard(converter)

# %% [markdown]
# Check the result by plotting the X-Y positions of the bodies.

# %%
from amuse.plot import scatter
def plot_snapshot(bodies):
    v = (bodies.vx**2 + bodies.vy**2 + bodies.vz**2).sqrt()
    scatter(bodies.x, bodies.y, c=v.value_in(units.kms), alpha=0.5)
    pyplot.colorbar()
    pyplot.show()
plot_snapshot(bodies)

# %%
from amuse.community.ph4.interface import ph4
from amuse.ext.LagrangianRadii import LagrangianRadii

gravity = ph4(converter)
gravity.particles.add_particles(bodies)
# A channel is a 'permanent' connection to a code's particle
# set. Multiple calls to a code's particle set need to set up
# a new connection every time; with a channel, we can copy
# information back without opening a new connection.
# This does not automatically update bodies! See below
channel = gravity.particles.new_channel_to(bodies)


times = numpy.arange(0, 100, 0.1) | units.Myr
RL25 = [] | units.parsec
Rvir = [] | units.parsec
for time in times:
    gravity.evolve_model(time)
    channel.copy() # Copy from gravity.particles to bodies
    Rvir.append(bodies.virial_radius())
    L = LagrangianRadii(bodies)
    RL25.append(LagrangianRadii(bodies)[5])

    if not time.value_in(units.Myr)%10.0:
        print("cluster at Time=", time.in_(units.Myr), 
              "Mass=", bodies.mass.sum().in_(units.MSun),
              "Rvir=", Rvir[-1].in_(units.parsec))
    b = bodies.get_binaries()
    if(len(b)>0):
        print("Number of binaries found:", len(b))
        print("first binary:", b[0])

pyplot.plot(times.value_in(units.Myr), RL25.value_in(units.parsec))
pyplot.plot(times.value_in(units.Myr), Rvir.value_in(units.parsec))
pyplot.show()
# Out:
# cluster at Time= 0.0 Myr Mass= 38.2919340312 MSun Rvir= 1.0 parsec
# cluster at Time= 10.0 Myr Mass= 38.2919340312 MSun Rvir= 1.01878487842 parsec
# cluster at Time= 20.0 Myr Mass= 38.2919340312 MSun Rvir= 0.823780534871 parsec
# cluster at Time= 30.0 Myr Mass= 38.2919340312 MSun Rvir= 1.071635634 parsec
# cluster at Time= 40.0 Myr Mass= 38.2919340312 MSun Rvir= 0.780298683338 parsec
# cluster at Time= 50.0 Myr Mass= 38.2919340312 MSun Rvir= 0.917734394807 parsec
# cluster at Time= 60.0 Myr Mass= 38.2919340312 MSun Rvir= 0.66952123365 parsec
# cluster at Time= 70.0 Myr Mass= 38.2919340312 MSun Rvir= 0.572221654249 parsec
# cluster at Time= 80.0 Myr Mass= 38.2919340312 MSun Rvir= 0.758361106436 parsec
# cluster at Time= 90.0 Myr Mass= 38.2919340312 MSun Rvir= 0.686033743618 parsec

# %% [markdown]
# You have now calculated the dynamical evolution of a small cluster of stars including a realistic mass function.
#
# Assignments and questions:
# ---------------
#
# ### Question 1:
# Why do we have to *scale_to_standard()* after assigning the masses and positions to all the particles?
#
# ### Question 2:
# Run the notebook and describe the evolution of the virial radius.
#
# ### Assignment 2:
# There is a check for binary detection in the script.
# If no binary formed in your run, that is okay.
#
# Run the script again until a binary forms.
#
# ### Question 3:
# One of the parameters in the binary is the *hardness*.
# What is the hardness of the binary from your last run? and explain what is meant with this parameter.
#
# ### Assignment 3:
# Rewrite the script in such a way that the event loop over time continues indefinitely, but that the code stops as soon as the first binary is detected.
#
# Run the script several times until you have enough first binaries formed to make a histogram of the first-binary formation time-scale.
#
# Now, make a small change to your initial conditions.
# A variation could include the dimensionless depth of the potential of the initial King model, the slope of the initial-mass function, its lower limit, or the number of stars in the simulation).
#
# Now redo the calculation in which you generate a histogram of moments of first-binary formation.
#
# Make one figure with both distributions: the original distribution for first-binary formation time and the second series of runs (with the altered initial conditions.
# Present both distributions as histograms and as cumulative distributions.
#
# ### Question 4:
# Can you understand the difference in first-binary formation-time based on the changes you introduced in the initial conditions?
#
# Did you perform enough runs to make a statistically significant statement about the time of first-binary formation?
#
# ### Assignment 4:
# Make a cumulative distribution of the masses of the two stars for each first binary and compare it to the initial mass-function.
#
# ### Question 5:
# Can you understand the difference between the typical masses of the binaries that formed first and the initial mass-function?

# %% [markdown]
# ### Question 1
# To make the system have consistent untis.

# %% [markdown]
# ### Question 2
# The Virial system oscillates around 1 parsec.

# %% [markdown]
# ### Assignment 2

# %%
# Initialzation 
r_cluster = 1.0 | units.parsec
from amuse.units import nbody_system
converter=nbody_system.nbody_to_si(m_stars.sum(),r_cluster)
from amuse.ic.kingmodel import new_king_model
W0 = 3.0
bodies=new_king_model(n_stars, W0, convert_nbody=converter)
m_stars.in_(units.MSun)
bodies.scale_to_standard(converter)


from amuse.community.ph4.interface import ph4
from amuse.ext.LagrangianRadii import LagrangianRadii

gravity = ph4(converter)
gravity.particles.add_particles(bodies)
# A channel is a 'permanent' connection to a code's particle
# set. Multiple calls to a code's particle set need to set up
# a new connection every time; with a channel, we can copy
# information back without opening a new connection.
# This does not automatically update bodies! See below
channel = gravity.particles.new_channel_to(bodies)


times = numpy.arange(0, 1000, 0.1) | units.Myr
RL25 = [] | units.parsec
Rvir = [] | units.parsec
for i, time in enumerate(times):
    gravity.evolve_model(time)
    channel.copy() # Copy from gravity.particles to bodies
    Rvir.append(bodies.virial_radius())
    L = LagrangianRadii(bodies)
    RL25.append(LagrangianRadii(bodies)[5])

    if not time.value_in(units.Myr)%10.0:
        print("cluster at Time=", time.in_(units.Myr), 
              "Mass=", bodies.mass.sum().in_(units.MSun),
              "Rvir=", Rvir[-1].in_(units.parsec))
    b = bodies.get_binaries()
    if(len(b)>0):
        print("Number of binaries found:", len(b))
        print("first binary:", b[0])
        break
        
pyplot.plot(times[:i+1].value_in(units.Myr), RL25.value_in(units.parsec))
pyplot.plot(times[:i+1].value_in(units.Myr), Rvir.value_in(units.parsec))
pyplot.show()
# Out:
# cluster at Time= 0.0 Myr Mass= 38.2919340312 MSun Rvir= 1.0 parsec
# cluster at Time= 10.0 Myr Mass= 38.2919340312 MSun Rvir= 1.00141195461 parsec
# cluster at Time= 20.0 Myr Mass= 38.2919340312 MSun Rvir= 0.971367022779 parsec
# cluster at Time= 30.0 Myr Mass= 38.2919340312 MSun Rvir= 1.0282579862 parsec
# cluster at Time= 40.0 Myr Mass= 38.2919340312 MSun Rvir= 1.03811553772 parsec
# cluster at Time= 50.0 Myr Mass= 38.2919340312 MSun Rvir= 1.04162000475 parsec
# cluster at Time= 60.0 Myr Mass= 38.2919340312 MSun Rvir= 0.993696254572 parsec
# cluster at Time= 70.0 Myr Mass= 38.2919340312 MSun Rvir= 1.12907738974 parsec
# cluster at Time= 80.0 Myr Mass= 38.2919340312 MSun Rvir= 0.920913800807 parsec
# cluster at Time= 90.0 Myr Mass= 38.2919340312 MSun Rvir= 1.04192241162 parsec
# Number of binaries found: 1
# first binary:                  key     hardness         mass  potential_in_code       radius     timestep           vx           vy           vz            x            y            z
#                    -         none           kg  m**2 * s**-2            m            s    m * s**-1    m * s**-1    m * s**-1            m            m            m
# ====================  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========
#  1241411375057120210    1.096e+01    7.616e+29   -5.280e+05    0.000e+00    1.856e+10   -1.930e+02   -3.540e+01   -2.845e+02   -8.498e+15    6.422e+15   -4.355e+15
#  2999301181110525278    1.096e+01    7.616e+29   -5.266e+05    0.000e+00    1.856e+10   -2.634e+02    3.667e+02   -1.831e+02   -8.462e+15    6.564e+15   -4.476e+15
# ====================  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========

# %% [markdown]
# ### Question 3
# It is how hard the binary could be seperated by interuptions.

# %% [markdown]
# ### Assignment 3

# %%
repeat = 200
first_binary_timescale = numpy.zeros(repeat) | units.Myr
binary_mass = numpy.array([]) | units.MSun

m_stars = new_powerlaw_mass_distribution(n_stars, 0.1|units.MSun, 
                                        100|units.MSun, alpha_IMF)

for n in range(repeat):
    
    # Initialzation
    r_cluster = 1.0 | units.parsec
    
    converter=nbody_system.nbody_to_si(m_stars.sum(),r_cluster)
    
    W0 = 3.0
    bodies=new_king_model(n_stars, W0, convert_nbody=converter)
    bodies.mass = m_stars.in_(units.MSun)
    bodies.scale_to_standard(converter)
    

    gravity = ph4(converter)
    gravity.particles.add_particles(bodies)
    # A channel is a 'permanent' connection to a code's particle
    # set. Multiple calls to a code's particle set need to set up
    # a new connection every time; with a channel, we can copy
    # information back without opening a new connection.
    # This does not automatically update bodies! See below
    channel = gravity.particles.new_channel_to(bodies)


    times = numpy.arange(0, 1000, 0.1) | units.Myr
    RL25 = [] | units.parsec
    Rvir = [] | units.parsec
    for i, time in enumerate(times):
        gravity.evolve_model(time)
        channel.copy() # Copy from gravity.particles to bodies
        Rvir.append(bodies.virial_radius())
        L = LagrangianRadii(bodies)
        RL25.append(LagrangianRadii(bodies)[5])
        
        b = bodies.get_binaries()
        if(len(b)>0):
            print(f"Repeat{n+1}, first binaries found:", time.in_(units.Myr))
            first_binary_timescale[n] = time.in_(units.Myr)
            for binary in b:
                binary_mass = numpy.append(binary_mass, 
                                           [binary[0].mass.value_in(units.MSun), 
                                            binary[1].mass.value_in(units.MSun)])
            break
            
binary_mass = binary_mass | units.MSun
# Out:
# Repeat1, first binaries found: 27.9 Myr
# Repeat2, first binaries found: 56.7 Myr
# Repeat3, first binaries found: 18.3 Myr
# Repeat4, first binaries found: 15.7 Myr
# Repeat5, first binaries found: 49.1 Myr
# Repeat6, first binaries found: 2.2 Myr
# Repeat7, first binaries found: 110.9 Myr
# Repeat8, first binaries found: 8.0 Myr
# Repeat9, first binaries found: 98.6 Myr
# Repeat10, first binaries found: 3.0 Myr
# Repeat11, first binaries found: 39.2 Myr
# Repeat12, first binaries found: 16.9 Myr
# Repeat13, first binaries found: 9.0 Myr
# Repeat14, first binaries found: 28.5 Myr
# Repeat15, first binaries found: 2.4 Myr
# Repeat16, first binaries found: 47.2 Myr
# Repeat17, first binaries found: 5.9 Myr
# Repeat18, first binaries found: 0.4 Myr
# Repeat19, first binaries found: 196.3 Myr
# Repeat20, first binaries found: 39.2 Myr
# Repeat21, first binaries found: 0.7 Myr
# Repeat22, first binaries found: 9.4 Myr
# Repeat23, first binaries found: 13.9 Myr
# Repeat24, first binaries found: 0.1 Myr
# Repeat25, first binaries found: 18.6 Myr
# Repeat26, first binaries found: 21.3 Myr
# Repeat27, first binaries found: 9.9 Myr
# Repeat28, first binaries found: 63.1 Myr
# Repeat29, first binaries found: 10.1 Myr
# Repeat30, first binaries found: 35.1 Myr
# Repeat31, first binaries found: 57.4 Myr
# Repeat32, first binaries found: 3.5 Myr
# Repeat33, first binaries found: 70.1 Myr
# Repeat34, first binaries found: 0.9 Myr
# Repeat35, first binaries found: 7.2 Myr
# Repeat36, first binaries found: 16.5 Myr
# Repeat37, first binaries found: 31.6 Myr
# Repeat38, first binaries found: 71.9 Myr
# Repeat39, first binaries found: 6.9 Myr
# Repeat40, first binaries found: 15.3 Myr
# Repeat41, first binaries found: 7.6 Myr
# Repeat42, first binaries found: 5.3 Myr
# Repeat43, first binaries found: 1.0 Myr
# Repeat44, first binaries found: 3.1 Myr
# Repeat45, first binaries found: 21.2 Myr
# Repeat46, first binaries found: 30.8 Myr
# Repeat47, first binaries found: 38.9 Myr
# Repeat48, first binaries found: 30.6 Myr
# Repeat49, first binaries found: 20.1 Myr
# Repeat50, first binaries found: 13.8 Myr
# Repeat51, first binaries found: 4.8 Myr
# Repeat52, first binaries found: 44.1 Myr
# Repeat53, first binaries found: 30.9 Myr
# Repeat54, first binaries found: 8.5 Myr
# Repeat55, first binaries found: 0.8 Myr
# Repeat56, first binaries found: 11.0 Myr
# Repeat57, first binaries found: 37.5 Myr
# Repeat58, first binaries found: 4.7 Myr
# Repeat59, first binaries found: 21.9 Myr
# Repeat60, first binaries found: 22.7 Myr
# Repeat61, first binaries found: 36.0 Myr
# Repeat62, first binaries found: 54.2 Myr
# Repeat63, first binaries found: 17.0 Myr
# Repeat64, first binaries found: 73.7 Myr
# Repeat65, first binaries found: 24.9 Myr
# Repeat66, first binaries found: 17.5 Myr
# Repeat67, first binaries found: 33.8 Myr
# Repeat68, first binaries found: 0.7 Myr
# Repeat69, first binaries found: 10.8 Myr
# Repeat70, first binaries found: 82.3 Myr
# Repeat71, first binaries found: 46.3 Myr
# Repeat72, first binaries found: 3.0 Myr
# Repeat73, first binaries found: 16.8 Myr
# Repeat74, first binaries found: 71.1 Myr
# Repeat75, first binaries found: 17.1 Myr
# Repeat76, first binaries found: 2.0 Myr
# Repeat77, first binaries found: 26.8 Myr
# Repeat78, first binaries found: 28.9 Myr
# Repeat79, first binaries found: 8.8 Myr
# Repeat80, first binaries found: 31.8 Myr
# Repeat81, first binaries found: 127.0 Myr
# Repeat82, first binaries found: 36.6 Myr
# Repeat83, first binaries found: 21.1 Myr
# Repeat84, first binaries found: 5.0 Myr
# Repeat85, first binaries found: 103.6 Myr
# Repeat86, first binaries found: 39.4 Myr
# Repeat87, first binaries found: 40.1 Myr
# Repeat88, first binaries found: 55.2 Myr
# Repeat89, first binaries found: 9.2 Myr
# Repeat90, first binaries found: 7.7 Myr
# Repeat91, first binaries found: 15.5 Myr
# Repeat92, first binaries found: 12.0 Myr
# Repeat93, first binaries found: 18.3 Myr
# Repeat94, first binaries found: 77.0 Myr
# Repeat95, first binaries found: 21.0 Myr
# Repeat96, first binaries found: 3.2 Myr
# Repeat97, first binaries found: 6.4 Myr
# Repeat98, first binaries found: 1.0 Myr
# Repeat99, first binaries found: 4.7 Myr
# Repeat100, first binaries found: 24.3 Myr
# Repeat101, first binaries found: 18.3 Myr
# Repeat102, first binaries found: 3.0 Myr
# Repeat103, first binaries found: 40.5 Myr
# Repeat104, first binaries found: 74.1 Myr
# Repeat105, first binaries found: 8.2 Myr
# Repeat106, first binaries found: 72.7 Myr
# Repeat107, first binaries found: 21.4 Myr
# Repeat108, first binaries found: 45.3 Myr
# Repeat109, first binaries found: 33.2 Myr
# Repeat110, first binaries found: 54.8 Myr
# Repeat111, first binaries found: 7.9 Myr
# Repeat112, first binaries found: 42.4 Myr
# Repeat113, first binaries found: 6.1 Myr
# Repeat114, first binaries found: 2.2 Myr
# Repeat115, first binaries found: 26.2 Myr
# Repeat116, first binaries found: 3.2 Myr
# Repeat117, first binaries found: 80.6 Myr
# Repeat118, first binaries found: 14.7 Myr
# Repeat119, first binaries found: 6.4 Myr
# Repeat120, first binaries found: 4.1 Myr
# Repeat121, first binaries found: 2.5 Myr
# Repeat122, first binaries found: 32.3 Myr
# Repeat123, first binaries found: 0.6 Myr
# Repeat124, first binaries found: 46.2 Myr
# Repeat125, first binaries found: 0.7 Myr
# Repeat126, first binaries found: 1.7 Myr
# Repeat127, first binaries found: 71.5 Myr
# Repeat128, first binaries found: 15.2 Myr
# Repeat129, first binaries found: 0.3 Myr
# Repeat130, first binaries found: 57.9 Myr
# Repeat131, first binaries found: 37.6 Myr
# Repeat132, first binaries found: 28.3 Myr
# Repeat133, first binaries found: 14.0 Myr
# Repeat134, first binaries found: 1.6 Myr
# Repeat135, first binaries found: 47.9 Myr
# Repeat136, first binaries found: 18.5 Myr
# Repeat137, first binaries found: 25.1 Myr
# Repeat138, first binaries found: 4.1 Myr
# Repeat139, first binaries found: 39.6 Myr
# Repeat140, first binaries found: 3.8 Myr
# Repeat141, first binaries found: 4.1 Myr
# Repeat142, first binaries found: 16.7 Myr
# Repeat143, first binaries found: 77.5 Myr
# Repeat144, first binaries found: 8.3 Myr
# Repeat145, first binaries found: 43.6 Myr
# Repeat146, first binaries found: 13.1 Myr
# Repeat147, first binaries found: 8.6 Myr
# Repeat148, first binaries found: 23.4 Myr
# Repeat149, first binaries found: 2.0 Myr
# Repeat150, first binaries found: 10.9 Myr
# Repeat151, first binaries found: 0.9 Myr
# Repeat152, first binaries found: 16.3 Myr
# Repeat153, first binaries found: 22.4 Myr
# Repeat154, first binaries found: 83.7 Myr
# Repeat155, first binaries found: 25.4 Myr
# Repeat156, first binaries found: 1.3 Myr
# Repeat157, first binaries found: 48.5 Myr
# Repeat158, first binaries found: 9.0 Myr
# Repeat159, first binaries found: 67.8 Myr
# Repeat160, first binaries found: 0.4 Myr
# Repeat161, first binaries found: 20.6 Myr
# Repeat162, first binaries found: 102.3 Myr
# Repeat163, first binaries found: 1.2 Myr
# Repeat164, first binaries found: 61.0 Myr
# Repeat165, first binaries found: 4.3 Myr
# Repeat166, first binaries found: 37.7 Myr
# Repeat167, first binaries found: 12.4 Myr
# Repeat168, first binaries found: 4.0 Myr
# Repeat169, first binaries found: 12.7 Myr
# Repeat170, first binaries found: 32.8 Myr
# Repeat171, first binaries found: 2.9 Myr
# Repeat172, first binaries found: 6.0 Myr
# Repeat173, first binaries found: 8.2 Myr
# Repeat174, first binaries found: 4.9 Myr
# Repeat175, first binaries found: 77.6 Myr
# Repeat176, first binaries found: 6.9 Myr
# Repeat177, first binaries found: 0.2 Myr
# Repeat178, first binaries found: 11.8 Myr
# Repeat179, first binaries found: 44.7 Myr
# Repeat180, first binaries found: 16.8 Myr
# Repeat181, first binaries found: 1.3 Myr
# Repeat182, first binaries found: 33.8 Myr
# Repeat183, first binaries found: 64.6 Myr
# Repeat184, first binaries found: 12.8 Myr
# Repeat185, first binaries found: 1.1 Myr
# Repeat186, first binaries found: 60.1 Myr
# Repeat187, first binaries found: 98.9 Myr
# Repeat188, first binaries found: 60.2 Myr
# Repeat189, first binaries found: 87.2 Myr
# Repeat190, first binaries found: 21.8 Myr
# Repeat191, first binaries found: 1.2 Myr
# Repeat192, first binaries found: 2.3 Myr
# Repeat193, first binaries found: 26.7 Myr
# Repeat194, first binaries found: 52.5 Myr
# Repeat195, first binaries found: 1.3 Myr
# Repeat196, first binaries found: 95.1 Myr
# Repeat197, first binaries found: 13.1 Myr
# Repeat198, first binaries found: 18.9 Myr
# Repeat199, first binaries found: 0.8 Myr
# Repeat200, first binaries found: 0.3 Myr

# %%
first_binary_timescale_new = numpy.zeros(repeat) | units.Myr
binary_mass_new = numpy.array([]) | units.MSun

for n in range(repeat):
    
    # Initialzation
    r_cluster = 1.0 | units.parsec
    
    converter=nbody_system.nbody_to_si(m_stars.sum(),r_cluster)
    
    W0 = 3.0
    bodies=new_king_model(n_stars, W0, convert_nbody=converter)
    bodies.mass = m_stars.in_(units.MSun)
    bodies.scale_to_standard(converter)
    

    gravity = ph4(converter)
    gravity.particles.add_particles(bodies)
    # A channel is a 'permanent' connection to a code's particle
    # set. Multiple calls to a code's particle set need to set up
    # a new connection every time; with a channel, we can copy
    # information back without opening a new connection.
    # This does not automatically update bodies! See below
    channel = gravity.particles.new_channel_to(bodies)


    times = numpy.arange(0, 1000, 0.1) | units.Myr
    RL25 = [] | units.parsec
    Rvir = [] | units.parsec
    for i, time in enumerate(times):
        gravity.evolve_model(time)
        channel.copy() # Copy from gravity.particles to bodies
        Rvir.append(bodies.virial_radius())
        L = LagrangianRadii(bodies)
        RL25.append(LagrangianRadii(bodies)[5])
        
        b = bodies.get_binaries()
        if(len(b)>0):
            print(f"Repeat{n+1}, first of binaries found:", time.in_(units.Myr))
            first_binary_timescale_new[n] = time.in_(units.Myr)
            for binary in b:
                binary_mass_new = numpy.append(binary_mass_new, 
                                               [binary[0].mass.value_in(units.MSun), 
                                                binary[1].mass.value_in(units.MSun)])
            break
            
binary_mass_new = binary_mass_new | units.MSun
# Out:
# Exception ignored in: <function CodeInterface.__del__ at 0x7f8057dfec20>
# Traceback (most recent call last):
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 755, in __del__
#     self._stop()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 845, in _stop
#     self._stop_worker()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 123, in __call__
#     raise exceptions.CodeException("Exception when calling function '{0}', of code '{1}', exception was '{2}'".format(self.specification.name, type(self.interface).__name__, ex))
# amuse.support.exceptions.CodeException: Exception when calling function '_stop_worker', of code 'ph4Interface', exception was '[Errno 32] Broken pipe'
# Exception ignored in: <function CodeInterface.__del__ at 0x7f8057dfec20>
# Traceback (most recent call last):
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 755, in __del__
#     self._stop()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 845, in _stop
#     self._stop_worker()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 123, in __call__
#     raise exceptions.CodeException("Exception when calling function '{0}', of code '{1}', exception was '{2}'".format(self.specification.name, type(self.interface).__name__, ex))
# amuse.support.exceptions.CodeException: Exception when calling function '_stop_worker', of code 'ph4Interface', exception was '[Errno 32] Broken pipe'
# Repeat1, first of binaries found: 7.7 Myr
# Repeat2, first of binaries found: 66.1 Myr
# Repeat3, first of binaries found: 8.2 Myr
# Repeat4, first of binaries found: 80.7 Myr
# Repeat5, first of binaries found: 3.3 Myr
# Repeat6, first of binaries found: 3.4 Myr
# Repeat7, first of binaries found: 38.1 Myr
# Repeat8, first of binaries found: 28.1 Myr
# Repeat9, first of binaries found: 27.9 Myr
# Repeat10, first of binaries found: 15.8 Myr
# Repeat11, first of binaries found: 12.7 Myr
# Repeat12, first of binaries found: 16.9 Myr
# Repeat13, first of binaries found: 5.0 Myr
# Repeat14, first of binaries found: 19.8 Myr
# Repeat15, first of binaries found: 54.7 Myr
# Repeat16, first of binaries found: 21.8 Myr
# Repeat17, first of binaries found: 16.6 Myr
# Repeat18, first of binaries found: 45.4 Myr
# Repeat19, first of binaries found: 31.1 Myr
# Repeat20, first of binaries found: 2.7 Myr
# Repeat21, first of binaries found: 22.7 Myr
# Repeat22, first of binaries found: 66.0 Myr
# Repeat23, first of binaries found: 42.0 Myr
# Repeat24, first of binaries found: 7.5 Myr
# Repeat25, first of binaries found: 5.8 Myr
# Repeat26, first of binaries found: 49.6 Myr
# Repeat27, first of binaries found: 44.3 Myr
# Repeat28, first of binaries found: 3.3 Myr
# Repeat29, first of binaries found: 20.7 Myr
# Repeat30, first of binaries found: 10.2 Myr
# Repeat31, first of binaries found: 39.2 Myr
# Repeat32, first of binaries found: 65.1 Myr
# Exception ignored in: <function CodeInterface.__del__ at 0x7f8057dfec20>
# Traceback (most recent call last):
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 755, in __del__
#     self._stop()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 845, in _stop
#     self._stop_worker()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 123, in __call__
#     raise exceptions.CodeException("Exception when calling function '{0}', of code '{1}', exception was '{2}'".format(self.specification.name, type(self.interface).__name__, ex))
# amuse.support.exceptions.CodeException: Exception when calling function '_stop_worker', of code 'ph4Interface', exception was '[Errno 32] Broken pipe'
# Exception ignored in: <function CodeInterface.__del__ at 0x7f8057dfec20>
# Traceback (most recent call last):
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 755, in __del__
#     self._stop()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 845, in _stop
#     self._stop_worker()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 123, in __call__
#     raise exceptions.CodeException("Exception when calling function '{0}', of code '{1}', exception was '{2}'".format(self.specification.name, type(self.interface).__name__, ex))
# amuse.support.exceptions.CodeException: Exception when calling function '_stop_worker', of code 'ph4Interface', exception was '[Errno 32] Broken pipe'
# Exception ignored in: <function CodeInterface.__del__ at 0x7f8057dfec20>
# Traceback (most recent call last):
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 755, in __del__
#     self._stop()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 845, in _stop
#     self._stop_worker()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 123, in __call__
#     raise exceptions.CodeException("Exception when calling function '{0}', of code '{1}', exception was '{2}'".format(self.specification.name, type(self.interface).__name__, ex))
# amuse.support.exceptions.CodeException: Exception when calling function '_stop_worker', of code 'ph4Interface', exception was '[Errno 32] Broken pipe'
# Exception ignored in: <function CodeInterface.__del__ at 0x7f8057dfec20>
# Traceback (most recent call last):
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 755, in __del__
#     self._stop()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 845, in _stop
#     self._stop_worker()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 123, in __call__
#     raise exceptions.CodeException("Exception when calling function '{0}', of code '{1}', exception was '{2}'".format(self.specification.name, type(self.interface).__name__, ex))
# amuse.support.exceptions.CodeException: Exception when calling function '_stop_worker', of code 'ph4Interface', exception was '[Errno 32] Broken pipe'
# Exception ignored in: <function CodeInterface.__del__ at 0x7f8057dfec20>
# Traceback (most recent call last):
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 755, in __del__
#     self._stop()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 845, in _stop
#     self._stop_worker()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 123, in __call__
#     raise exceptions.CodeException("Exception when calling function '{0}', of code '{1}', exception was '{2}'".format(self.specification.name, type(self.interface).__name__, ex))
# amuse.support.exceptions.CodeException: Exception when calling function '_stop_worker', of code 'ph4Interface', exception was '[Errno 32] Broken pipe'
# Exception ignored in: <function CodeInterface.__del__ at 0x7f8057dfec20>
# Traceback (most recent call last):
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 755, in __del__
#     self._stop()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 845, in _stop
#     self._stop_worker()
#   File "/software/amuse/amuse-2021.6/lib/python3.9/site-packages/amuse/rfi/core.py", line 123, in __call__
#     raise exceptions.CodeException("Exception when calling function '{0}', of code '{1}', exception was '{2}'".format(self.specification.name, type(self.interface).__name__, ex))
# amuse.support.exceptions.CodeException: Exception when calling function '_stop_worker', of code 'ph4Interface', exception was '[Errno 32] Broken pipe'
# Repeat33, first of binaries found: 21.1 Myr
# Repeat34, first of binaries found: 14.3 Myr
# Repeat35, first of binaries found: 50.9 Myr
# Repeat36, first of binaries found: 35.8 Myr
# Repeat37, first of binaries found: 659.3 Myr
# Repeat38, first of binaries found: 11.7 Myr
# Repeat39, first of binaries found: 14.5 Myr
# Repeat40, first of binaries found: 7.4 Myr
# Repeat41, first of binaries found: 75.8 Myr
# Repeat42, first of binaries found: 103.0 Myr
# Repeat43, first of binaries found: 34.6 Myr
# Repeat44, first of binaries found: 32.6 Myr
# Repeat45, first of binaries found: 28.8 Myr
# Repeat46, first of binaries found: 30.0 Myr
# Repeat47, first of binaries found: 35.0 Myr
# Repeat48, first of binaries found: 5.6 Myr
# Repeat49, first of binaries found: 11.8 Myr
# Repeat50, first of binaries found: 26.8 Myr
# Repeat51, first of binaries found: 0.7 Myr
# Repeat52, first of binaries found: 40.3 Myr
# Repeat53, first of binaries found: 27.5 Myr
# Repeat54, first of binaries found: 26.7 Myr
# Repeat55, first of binaries found: 23.6 Myr
# Repeat56, first of binaries found: 12.3 Myr
# Repeat57, first of binaries found: 49.9 Myr
# Repeat58, first of binaries found: 44.1 Myr
# Repeat59, first of binaries found: 26.4 Myr
# Repeat60, first of binaries found: 59.6 Myr
# Repeat61, first of binaries found: 4.0 Myr
# Repeat62, first of binaries found: 3.6 Myr
# Repeat63, first of binaries found: 15.4 Myr
# Repeat64, first of binaries found: 4.1 Myr
# Repeat65, first of binaries found: 2.0 Myr
# Repeat66, first of binaries found: 47.8 Myr
# Repeat67, first of binaries found: 27.8 Myr
# Repeat68, first of binaries found: 41.2 Myr
# Repeat69, first of binaries found: 0.0 Myr
# Repeat70, first of binaries found: 8.0 Myr
# Repeat71, first of binaries found: 33.0 Myr
# Repeat72, first of binaries found: 17.8 Myr
# Repeat73, first of binaries found: 4.8 Myr
# Repeat74, first of binaries found: 28.5 Myr
# Repeat75, first of binaries found: 54.0 Myr
# Repeat76, first of binaries found: 20.9 Myr
# Repeat77, first of binaries found: 0.7 Myr
# Repeat78, first of binaries found: 6.0 Myr
# Repeat79, first of binaries found: 21.8 Myr
# Repeat80, first of binaries found: 8.8 Myr
# Repeat81, first of binaries found: 9.2 Myr
# Repeat82, first of binaries found: 19.5 Myr
# Repeat83, first of binaries found: 4.6 Myr
# Repeat84, first of binaries found: 49.9 Myr
# Repeat85, first of binaries found: 72.0 Myr
# Repeat86, first of binaries found: 13.5 Myr
# Repeat88, first of binaries found: 4.4 Myr
# Repeat89, first of binaries found: 28.6 Myr
# Repeat90, first of binaries found: 7.2 Myr
# Repeat91, first of binaries found: 8.8 Myr
# Repeat92, first of binaries found: 30.1 Myr
# Repeat93, first of binaries found: 1.1 Myr
# Repeat94, first of binaries found: 4.6 Myr
# Repeat95, first of binaries found: 43.8 Myr
# Repeat96, first of binaries found: 10.4 Myr
# Repeat97, first of binaries found: 85.8 Myr
# Repeat99, first of binaries found: 18.9 Myr
# Repeat100, first of binaries found: 20.8 Myr
# Repeat101, first of binaries found: 5.5 Myr
# Repeat102, first of binaries found: 1.8 Myr
# Repeat103, first of binaries found: 0.0 Myr
# Repeat104, first of binaries found: 8.9 Myr
# Repeat105, first of binaries found: 17.6 Myr
# Repeat106, first of binaries found: 17.2 Myr
# Repeat107, first of binaries found: 26.5 Myr
# Repeat108, first of binaries found: 10.5 Myr
# Repeat109, first of binaries found: 24.0 Myr
# Repeat110, first of binaries found: 5.5 Myr
# Repeat111, first of binaries found: 74.2 Myr
# Repeat112, first of binaries found: 19.7 Myr
# Repeat113, first of binaries found: 2.4 Myr
# Repeat114, first of binaries found: 34.1 Myr
# Repeat115, first of binaries found: 4.6 Myr
# Repeat116, first of binaries found: 23.0 Myr
# Repeat117, first of binaries found: 9.5 Myr
# Repeat118, first of binaries found: 0.8 Myr
# Repeat119, first of binaries found: 2.8 Myr
# Repeat120, first of binaries found: 4.9 Myr
# Repeat121, first of binaries found: 54.2 Myr
# Repeat122, first of binaries found: 6.4 Myr
# Repeat123, first of binaries found: 37.3 Myr
# Repeat124, first of binaries found: 83.0 Myr
# Repeat125, first of binaries found: 9.0 Myr
# Repeat126, first of binaries found: 20.6 Myr
# Repeat127, first of binaries found: 5.0 Myr
# Repeat128, first of binaries found: 24.9 Myr
# Repeat129, first of binaries found: 112.1 Myr
# Repeat130, first of binaries found: 4.5 Myr
# Repeat131, first of binaries found: 99.0 Myr
# Repeat132, first of binaries found: 4.1 Myr
# Repeat133, first of binaries found: 6.6 Myr
# Repeat134, first of binaries found: 0.9 Myr
# Repeat135, first of binaries found: 69.4 Myr
# Repeat136, first of binaries found: 30.5 Myr
# Repeat137, first of binaries found: 2.6 Myr
# Repeat138, first of binaries found: 23.3 Myr
# Repeat139, first of binaries found: 8.1 Myr
# Repeat140, first of binaries found: 26.6 Myr
# Repeat141, first of binaries found: 9.1 Myr
# Repeat142, first of binaries found: 28.5 Myr
# Repeat143, first of binaries found: 44.3 Myr
# Repeat144, first of binaries found: 5.5 Myr
# Repeat145, first of binaries found: 58.5 Myr
# Repeat146, first of binaries found: 1.6 Myr
# Repeat147, first of binaries found: 10.5 Myr
# Repeat148, first of binaries found: 32.4 Myr
# Repeat149, first of binaries found: 33.5 Myr
# Repeat150, first of binaries found: 2.2 Myr
# Repeat151, first of binaries found: 5.4 Myr
# Repeat152, first of binaries found: 8.8 Myr
# Repeat153, first of binaries found: 65.9 Myr
# Repeat154, first of binaries found: 43.0 Myr
# Repeat155, first of binaries found: 1.3 Myr
# Repeat156, first of binaries found: 14.5 Myr
# Repeat157, first of binaries found: 2.0 Myr
# Repeat158, first of binaries found: 42.1 Myr
# Repeat159, first of binaries found: 7.5 Myr
# Repeat160, first of binaries found: 27.3 Myr
# Repeat161, first of binaries found: 75.4 Myr
# Repeat162, first of binaries found: 10.8 Myr
# Repeat163, first of binaries found: 4.3 Myr
# Repeat164, first of binaries found: 65.3 Myr
# Repeat165, first of binaries found: 63.0 Myr
# Repeat166, first of binaries found: 1.7 Myr
# Repeat167, first of binaries found: 0.9 Myr
# Repeat168, first of binaries found: 60.0 Myr
# Repeat169, first of binaries found: 27.2 Myr
# Repeat170, first of binaries found: 13.3 Myr
# Repeat171, first of binaries found: 19.9 Myr
# Repeat172, first of binaries found: 4.4 Myr
# Repeat173, first of binaries found: 78.1 Myr
# Repeat174, first of binaries found: 7.8 Myr
# Repeat175, first of binaries found: 1.0 Myr
# Repeat176, first of binaries found: 50.4 Myr
# Repeat177, first of binaries found: 26.1 Myr
# Repeat178, first of binaries found: 3.0 Myr
# Repeat179, first of binaries found: 17.4 Myr
# Repeat180, first of binaries found: 7.9 Myr
# Repeat181, first of binaries found: 1.0 Myr
# Repeat182, first of binaries found: 1.9 Myr
# Repeat183, first of binaries found: 32.1 Myr
# Repeat184, first of binaries found: 9.0 Myr
# Repeat185, first of binaries found: 51.7 Myr
# Repeat186, first of binaries found: 3.3 Myr
# Repeat187, first of binaries found: 30.6 Myr
# Repeat188, first of binaries found: 25.6 Myr
# Repeat189, first of binaries found: 2.2 Myr
# Repeat190, first of binaries found: 6.7 Myr
# Repeat191, first of binaries found: 7.4 Myr
# Repeat192, first of binaries found: 0.5 Myr
# Repeat193, first of binaries found: 27.7 Myr
# Repeat194, first of binaries found: 19.2 Myr
# Repeat195, first of binaries found: 16.5 Myr
# Repeat196, first of binaries found: 41.4 Myr
# Repeat197, first of binaries found: 5.8 Myr
# Repeat198, first of binaries found: 2.7 Myr
# Repeat199, first of binaries found: 27.2 Myr
# Repeat200, first of binaries found: 7.4 Myr

# %%
pyplot.hist(first_binary_timescale.value_in(units.Myr), range=(0,200), alpha=0.5, label='w=0.3');
pyplot.hist(first_binary_timescale_new.value_in(units.Myr), range=(0,200), alpha=0.5, label='w=0.6');
pyplot.xlabel('First Binary Found Time (Myr)')
pyplot.ylabel('Counts (200 in Total)');

# %% [markdown]
# ### Question 4
# idk What does depth in king model mean?

# %% [markdown]
# ### Assignment 4

# %%
plot_cdf(binary_mass_new)

# %% [markdown]
# ### Question 5

# %% [markdown]
# Why all masses are the same?
