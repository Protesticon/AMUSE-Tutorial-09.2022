# %% [markdown]
# How to run a star cluster simulation
# ====================
#
# More realistic star clusters have stars that move and evolve in time.
# The movement of stars is caused by their mutual gravity, which we will take care of by means of integrating the equations of motion under Newtonian forces. This is realized using, what we call, and N-body code. Stellar evolution influences the gravitational dynamics by altering the mass of the N-body particles. It is taken care of by means of a parametrized stellar evolution code.
#
# For reference you can read chapter 4 of Portegies Zwart & McMillan 2018 (2018araa.book.....P).
#
# With this tutorial you will learn
# - how to generate inital conditions (mass-function, Plummer model)
# - to initialize gravitational N-body codes and parametrized stellar evolution codes
# - channels and intra-code data transfer
# - plotting results

# %%
# %matplotlib inline
import numpy
from matplotlib import pyplot
from amuse.units import units

# %% [markdown]
# Let's start by generating the initial conditions.
# This includes a mass function (for which we adopt the Salpeter power-law), and a Plummer sphere for the spatial distribution. After assigning the masses to the stars in the Plummer sphere, we scale the entire system to virial equilibrium.

# %%
n_stars = 100
alpha_IMF = -2.35

from amuse.lab import new_powerlaw_mass_distribution
m_stars = new_powerlaw_mass_distribution(n_stars, 
                                         10.0|units.MSun, 
                                         100.0|units.MSun, 
                                         alpha_IMF)

r_cluster = 1.0 | units.parsec
from amuse.units import nbody_system
converter=nbody_system.nbody_to_si(m_stars.sum(), r_cluster)
from amuse.ic.plummer import new_plummer_model
stars=new_plummer_model(n_stars, convert_nbody=converter)
stars.mass = m_stars
stars.scale_to_standard(converter)

# %% [markdown]
# Let's check if this is what we expected.

# %%
def plot_snapshot(bodies):
    v = (bodies.vx**2 + bodies.vy**2 + bodies.vz**2).sqrt()
    s = bodies.mass.value_in(units.MSun)
    fig, (ax1, ax2) = pyplot.subplots(1, 2, figsize=(11, 3))
    ax1.scatter(stars.temperature.value_in(units.K),
                stars.luminosity.value_in(units.LSun), 
                c=v.value_in(units.kms),
                s=s)
    ax1.set_xlim(6.e+4, 20000)
    ax1.set_ylim(1.e+3, 1.e+7)
    ax1.loglog()
    ax1.set_xlabel("T [K]")
    ax1.set_ylabel("L [$L_\odot$]")
    ax2.scatter(bodies.x.value_in(units.pc), 
                bodies.y.value_in(units.pc), 
                c=v.value_in(units.kms), 
                s=s)
    pyplot.gca().set_aspect('equal', adjustable='box')
    ax2.set_xlabel("x [pc]")
    ax2.set_ylabel("y [pc]")
    ax2.set_xlim(-5, 5)
    ax2.set_ylim(-5, 5)
    pyplot.show()

# %%
from amuse.community.ph4.interface import ph4
from amuse.community.seba.interface import SeBa
from amuse.ext.LagrangianRadii import LagrangianRadii

stellar = SeBa()
stellar.particles.add_particles(stars)

gravity = ph4(converter)
gravity.particles.add_particles(stars)
ch_s2g = stellar.particles.new_channel_to(gravity.particles)
ch_g2l = gravity.particles.new_channel_to(stars)
ch_s2l = stellar.particles.new_channel_to(stars)
ch_s2l.copy()

plot_snapshot(stars)

# %% [markdown]
# Now let's run the code. Why is the coupling timescale between gravity and stellar evolution chosen the way it is?

# %%
end_time = 10.0 | units.Myr
model_time = 0 | units.Myr
while(model_time<end_time):
    dt = stellar.particles.time_step.min()
    model_time += dt
    stellar.evolve_model(model_time)
    ch_s2g.copy()
    ch_s2l.copy()
    gravity.evolve_model(model_time)
    ch_g2l.copy()
    print("Evolved to t=", stellar.model_time.in_(units.Myr), 
          gravity.model_time.in_(units.Myr),
         "mass=", stars.mass.sum().in_(units.MSun), 
          "rvir=", stars.virial_radius().in_(units.pc))
    
plot_snapshot(stars)
stellar.stop()
gravity.stop()
# Out:
# Evolved to t= 0.0318619353284 Myr 0.0320054471746 Myr mass= 2151.98157208 MSun rvir= 1.00429315583 parsec
# Evolved to t= 0.0636083957377 Myr 0.0636971154553 Myr mass= 2151.21359225 MSun rvir= 1.00687848095 parsec
# Evolved to t= 0.0953242890113 Myr 0.095388783736 Myr mass= 2150.44174778 MSun rvir= 1.01488217041 parsec
# Evolved to t= 0.127009055851 Myr 0.127080452017 Myr mass= 2149.66602192 MSun rvir= 1.00981796241 parsec
# Evolved to t= 0.158662385608 Myr 0.158772120297 Myr mass= 2148.88639201 MSun rvir= 1.00720458187 parsec
# Evolved to t= 0.190283985776 Myr 0.190777567472 Myr mass= 2148.10283517 MSun rvir= 1.01394594001 parsec
# Evolved to t= 0.221873582661 Myr 0.222155456859 Myr mass= 2147.31532825 MSun rvir= 1.01869399373 parsec
# Evolved to t= 0.253430921417 Myr 0.253533346246 Myr mass= 2146.52384788 MSun rvir= 1.02122745807 parsec
# Evolved to t= 0.284955766063 Myr 0.28553879342 Myr mass= 2145.72837053 MSun rvir= 1.0242143044 parsec
# Evolved to t= 0.316447899489 Myr 0.316602903913 Myr mass= 2144.9288725 MSun rvir= 1.02689957961 parsec
# Evolved to t= 0.347907123442 Myr 0.3479807933 Myr mass= 2144.12532998 MSun rvir= 1.03507128556 parsec
# Evolved to t= 0.379333258512 Myr 0.379358682687 Myr mass= 2143.31771907 MSun rvir= 1.03982383652 parsec
# Evolved to t= 0.410726144083 Myr 0.411677908755 Myr mass= 2142.50601584 MSun rvir= 1.04461428579 parsec
# Evolved to t= 0.442085638291 Myr 0.443055798142 Myr mass= 2141.69019629 MSun rvir= 1.04717775459 parsec
# Evolved to t= 0.473411617955 Myr 0.473492350848 Myr mass= 2140.87023648 MSun rvir= 1.0533277256 parsec
# Evolved to t= 0.504703978496 Myr 0.505184019128 Myr mass= 2140.04611249 MSun rvir= 1.06187901179 parsec
# Evolved to t= 0.535962633852 Myr 0.536248129621 Myr mass= 2139.2178005 MSun rvir= 1.05879749634 parsec
# Evolved to t= 0.567187516367 Myr 0.567312240114 Myr mass= 2138.38527677 MSun rvir= 1.06803015167 parsec
# Evolved to t= 0.598378576671 Myr 0.598690129501 Myr mass= 2137.54851775 MSun rvir= 1.06144365301 parsec
# Evolved to t= 0.629535783556 Myr 0.630068018888 Myr mass= 2136.70750005 MSun rvir= 1.06474107033 parsec
# Evolved to t= 0.66065912382 Myr 0.660818350487 Myr mass= 2135.8622005 MSun rvir= 1.06194372364 parsec
# Evolved to t= 0.691748602118 Myr 0.692196239874 Myr mass= 2135.01259622 MSun rvir= 1.06279782461 parsec
# Evolved to t= 0.722804240782 Myr 0.722946571473 Myr mass= 2134.1586646 MSun rvir= 1.05529764208 parsec
# Evolved to t= 3.7863776611 Myr 3.78640913467 Myr mass= 2023.2005239 MSun rvir= 1.00431846651 parsec
# Evolved to t= 3.78637770128 Myr 3.78640913467 Myr mass= 2023.20052085 MSun rvir= 1.00431846665 parsec
# Evolved to t= 3.78637773837 Myr 3.78640913467 Myr mass= 2023.20051804 MSun rvir= 1.00431846678 parsec
# Evolved to t= 3.78637777261 Myr 3.78640913467 Myr mass= 2023.20051545 MSun rvir= 1.0043184669 parsec
# Evolved to t= 3.78637780421 Myr 3.78640913467 Myr mass= 2023.20051305 MSun rvir= 1.00431846702 parsec
# Evolved to t= 3.78637783338 Myr 3.78640913467 Myr mass= 2023.20051084 MSun rvir= 1.00431846712 parsec
# Evolved to t= 3.7863778603 Myr 3.78640913467 Myr mass= 2023.2005088 MSun rvir= 1.00431846722 parsec
# Evolved to t= 3.78637788516 Myr 3.78640913467 Myr mass= 2023.20050692 MSun rvir= 1.00431846731 parsec
# Evolved to t= 3.7863779081 Myr 3.78640913467 Myr mass= 2023.20050518 MSun rvir= 1.00431846739 parsec
# Evolved to t= 3.78637792927 Myr 3.78640913467 Myr mass= 2023.20050357 MSun rvir= 1.00431846746 parsec
# Evolved to t= 3.78637794882 Myr 3.78640913467 Myr mass= 2023.20050209 MSun rvir= 1.00431846753 parsec
# Evolved to t= 3.78637796686 Myr 3.78640913467 Myr mass= 2023.20050072 MSun rvir= 1.0043184676 parsec
# Evolved to t= 3.78637798352 Myr 3.78640913467 Myr mass= 2023.20049946 MSun rvir= 1.00431846766 parsec
# Evolved to t= 3.78637799889 Myr 3.78640913467 Myr mass= 2023.2004983 MSun rvir= 1.00431846771 parsec
# Evolved to t= 3.78637801308 Myr 3.78640913467 Myr mass= 2023.20049722 MSun rvir= 1.00431846776 parsec
# Evolved to t= 3.78637802618 Myr 3.78640913467 Myr mass= 2023.20049623 MSun rvir= 1.00431846781 parsec
# Evolved to t= 3.78637803827 Myr 3.78640913467 Myr mass= 2023.20049531 MSun rvir= 1.00431846785 parsec
# Evolved to t= 3.78637804943 Myr 3.78640913467 Myr mass= 2023.20049447 MSun rvir= 1.00431846789 parsec
# Evolved to t= 3.78637805974 Myr 3.78640913467 Myr mass= 2023.20049368 MSun rvir= 1.00431846793 parsec
# Evolved to t= 3.78637806924 Myr 3.78640913467 Myr mass= 2023.20049296 MSun rvir= 1.00431846796 parsec
# Evolved to t= 3.78637807802 Myr 3.78640913467 Myr mass= 2023.2004923 MSun rvir= 1.00431846799 parsec
# Evolved to t= 3.78637808612 Myr 3.78640913467 Myr mass= 2023.20049168 MSun rvir= 1.00431846802 parsec
# Evolved to t= 3.7863780936 Myr 3.78640913467 Myr mass= 2023.20049112 MSun rvir= 1.00431846805 parsec
# Evolved to t= 3.78637810051 Myr 3.78640913467 Myr mass= 2023.20049059 MSun rvir= 1.00431846807 parsec
# Evolved to t= 3.78637810688 Myr 3.78640913467 Myr mass= 2023.20049011 MSun rvir= 1.0043184681 parsec
# Evolved to t= 3.78637811276 Myr 3.78640913467 Myr mass= 2023.20048967 MSun rvir= 1.00431846812 parsec
# Evolved to t= 3.78637811819 Myr 3.78640913467 Myr mass= 2023.20048925 MSun rvir= 1.00431846814 parsec
# Evolved to t= 3.7863781232 Myr 3.78640913467 Myr mass= 2023.20048887 MSun rvir= 1.00431846816 parsec
# Evolved to t= 3.78637812783 Myr 3.78640913467 Myr mass= 2023.20048852 MSun rvir= 1.00431846817 parsec
# Evolved to t= 3.7863781321 Myr 3.78640913467 Myr mass= 2023.2004882 MSun rvir= 1.00431846819 parsec
# Evolved to t= 3.78637813604 Myr 3.78640913467 Myr mass= 2023.2004879 MSun rvir= 1.0043184682 parsec
# Evolved to t= 3.78637813968 Myr 3.78640913467 Myr mass= 2023.20048763 MSun rvir= 1.00431846821 parsec
# Evolved to t= 3.78637814304 Myr 3.78640913467 Myr mass= 2023.20048737 MSun rvir= 1.00431846823 parsec
# Evolved to t= 3.78637814614 Myr 3.78640913467 Myr mass= 2023.20048714 MSun rvir= 1.00431846824 parsec
# Evolved to t= 3.786378149 Myr 3.78640913467 Myr mass= 2023.20048692 MSun rvir= 1.00431846825 parsec
# Evolved to t= 3.78637815164 Myr 3.78640913467 Myr mass= 2023.20048672 MSun rvir= 1.00431846826 parsec
# Evolved to t= 3.78637815408 Myr 3.78640913467 Myr mass= 2023.20048653 MSun rvir= 1.00431846827 parsec
# Evolved to t= 3.78637815633 Myr 3.78640913467 Myr mass= 2023.20048636 MSun rvir= 1.00431846827 parsec
# Evolved to t= 3.78637815841 Myr 3.78640913467 Myr mass= 2023.20048621 MSun rvir= 1.00431846828 parsec
# Evolved to t= 3.78637816032 Myr 3.78640913467 Myr mass= 2023.20048606 MSun rvir= 1.00431846829 parsec
# Evolved to t= 3.78637816209 Myr 3.78640913467 Myr mass= 2023.20048593 MSun rvir= 1.00431846829 parsec
# Evolved to t= 3.78637816373 Myr 3.78640913467 Myr mass= 2023.2004858 MSun rvir= 1.0043184683 parsec
# Evolved to t= 3.78637816524 Myr 3.78640913467 Myr mass= 2023.20048569 MSun rvir= 1.00431846831 parsec
# Evolved to t= 3.78637816663 Myr 3.78640913467 Myr mass= 2023.20048558 MSun rvir= 1.00431846831 parsec
# Evolved to t= 3.78637816791 Myr 3.78640913467 Myr mass= 2023.20048549 MSun rvir= 1.00431846832 parsec
# Evolved to t= 3.7863781691 Myr 3.78640913467 Myr mass= 2023.2004854 MSun rvir= 1.00431846832 parsec
# Evolved to t= 3.78637817019 Myr 3.78640913467 Myr mass= 2023.20048531 MSun rvir= 1.00431846832 parsec
# Evolved to t= 3.7863781712 Myr 3.78640913467 Myr mass= 2023.20048524 MSun rvir= 1.00431846833 parsec
# Evolved to t= 3.7863781722 Myr 3.78640913467 Myr mass= 2023.20048516 MSun rvir= 1.00431846833 parsec
# Evolved to t= 3.7863781732 Myr 3.78640913467 Myr mass= 2023.20048508 MSun rvir= 1.00431846833 parsec
# Evolved to t= 3.7863781742 Myr 3.78640913467 Myr mass= 2023.20048501 MSun rvir= 1.00431846834 parsec
# Evolved to t= 3.90179039671 Myr 3.90184054525 Myr mass= 1983.20769113 MSun rvir= 0.915642790704 parsec
# Evolved to t= 3.90243602579 Myr 3.90246810304 Myr mass= 1983.15416901 MSun rvir= 0.917202183213 parsec
# Evolved to t= 3.90302607085 Myr 3.90309566083 Myr mass= 1983.10514308 MSun rvir= 0.918701488637 parsec
# Evolved to t= 3.90356541651 Myr 3.90356632917 Myr mass= 1983.06023467 MSun rvir= 0.91974527497 parsec
# Evolved to t= 3.904058505 Myr 3.90419388696 Myr mass= 1983.01909712 MSun rvir= 0.921017586969 parsec
# Evolved to t= 3.90450937763 Myr 3.9046645553 Myr mass= 1982.98141307 MSun rvir= 0.921905721909 parsec
# Evolved to t= 3.90492171236 Myr 3.90497833419 Myr mass= 1982.94689196 MSun rvir= 0.922480667672 parsec
# Evolved to t= 3.90529885769 Myr 3.90560589198 Myr mass= 1982.91526778 MSun rvir= 0.923610653905 parsec
# Evolved to t= 3.90564386336 Myr 3.90564511434 Myr mass= 1982.88629694 MSun rvir= 0.923688745491 parsec
# Evolved to t= 3.90595950801 Myr 3.90607656032 Myr mass= 1982.85975642 MSun rvir= 0.924488356192 parsec
# Evolved to t= 3.90624832421 Myr 3.90639033922 Myr mass= 1982.835442 MSun rvir= 0.925094596153 parsec
# Evolved to t= 3.90651262103 Myr 3.90654722866 Myr mass= 1982.81316667 MSun rvir= 0.925410002529 parsec
# Evolved to t= 3.90675450452 Myr 3.90686100756 Myr mass= 1982.79275918 MSun rvir= 0.926057018233 parsec
# Evolved to t= 3.90697589613 Myr 3.907017897 Myr mass= 1982.7740627 MSun rvir= 0.926395058096 parsec
# Evolved to t= 3.90717854944 Myr 3.9073316759 Myr mass= 1982.75693358 MSun rvir= 0.927092332536 parsec
# Evolved to t= 3.9073640653 Myr 3.90737089826 Myr mass= 1982.74124029 MSun rvir= 0.927185672003 parsec
# Evolved to t= 3.90753390552 Myr 3.90764545479 Myr mass= 1982.72686233 MSun rvir= 0.927830048901 parsec
# Evolved to t= 3.90768940526 Myr 3.90772389951 Myr mass= 1982.71368936 MSun rvir= 0.928021885632 parsec
# Evolved to t= 3.90783178433 Myr 3.90788078896 Myr mass= 1982.70162029 MSun rvir= 0.928408815636 parsec
# Evolved to t= 3.9079621574 Myr 3.90803767841 Myr mass= 1982.69056255 MSun rvir= 0.928804826838 parsec
# Evolved to t= 3.90808154324 Myr 3.90811612313 Myr mass= 1982.68043132 MSun rvir= 0.929007527065 parsec
# Evolved to t= 3.9081908732 Myr 3.90819456786 Myr mass= 1982.67114891 MSun rvir= 0.929212272621 parsec
# Evolved to t= 3.90829099882 Myr 3.9083514573 Myr mass= 1982.66264417 MSun rvir= 0.929625749448 parsec
# Evolved to t= 3.90838269882 Myr 3.90839067966 Myr mass= 1982.6548519 MSun rvir= 0.929732005997 parsec
# Evolved to t= 3.90846668545 Myr 3.90850834675 Myr mass= 1982.64771238 MSun rvir= 0.930049608467 parsec
# Evolved to t= 3.90854361024 Myr 3.90854756911 Myr mass= 1982.64117091 MSun rvir= 0.930157638755 parsec
# Evolved to t= 3.90861406924 Myr 3.9086652362 Myr mass= 1982.63517736 MSun rvir= 0.930481116461 parsec
# Evolved to t= 3.90867860786 Myr 3.90870445856 Myr mass= 1982.62968583 MSun rvir= 0.930590874081 parsec
# Evolved to t= 3.90873772517 Myr 3.90874368092 Myr mass= 1982.62465424 MSun rvir= 0.930700993383 parsec
# Evolved to t= 3.90879187793 Myr 3.90882212564 Myr mass= 1982.62004406 MSun rvir= 0.930921194536 parsec
# Evolved to t= 3.9088414842 Myr 3.908861348 Myr mass= 1982.61581999 MSun rvir= 0.93103250838 parsec
# Evolved to t= 3.90888692665 Myr 3.90890057037 Myr mass= 1982.61194968 MSun rvir= 0.93114418242 parsec
# Evolved to t= 3.90892855558 Myr 3.90893979273 Myr mass= 1982.60840349 MSun rvir= 0.931256216731 parsec
# Evolved to t= 3.90896669172 Myr 3.90897901509 Myr mass= 1982.60515427 MSun rvir= 0.931368610578 parsec
# Evolved to t= 3.90900162868 Myr 3.90901823745 Myr mass= 1982.60217715 MSun rvir= 0.931481362478 parsec
# ...
# Evolved to t= 9.61682214185 Myr 9.61732309707 Myr mass= 1211.43006576 MSun rvir= 3.24256228312 parsec
# Evolved to t= 9.61783083089 Myr 9.61795065486 Myr mass= 1211.40780789 MSun rvir= 3.24177627972 parsec
# Evolved to t= 9.61883488237 Myr 9.61920577043 Myr mass= 1211.38325694 MSun rvir= 3.24019502221 parsec
# Evolved to t= 9.61983433878 Myr 9.62046088601 Myr mass= 1211.35959788 MSun rvir= 3.23854687212 parsec
# Evolved to t= 9.62082924204 Myr 9.62108844379 Myr mass= 1211.33677035 MSun rvir= 3.23767024767 parsec
# Evolved to t= 9.6218196335 Myr 9.62234355937 Myr mass= 1211.31471839 MSun rvir= 3.23591185462 parsec
# Evolved to t= 9.62275378679 Myr 9.62297111716 Myr mass= 1211.29703061 MSun rvir= 3.23498547145 parsec
# Evolved to t= 9.62315769058 Myr 9.62328489605 Myr mass= 1211.28939483 MSun rvir= 3.2345170522 parsec
# Evolved to t= 9.6233337231 Myr 9.62336334078 Myr mass= 1211.28606874 MSun rvir= 3.23439581886 parsec
# Evolved to t= 9.62341070557 Myr 9.6234417855 Myr mass= 1211.28461448 MSun rvir= 3.23427856552 parsec
# Evolved to t= 9.62344442153 Myr 9.62352023022 Myr mass= 1211.28397762 MSun rvir= 3.23416285056 parsec
# Evolved to t= 9.62345919767 Myr 9.62352023022 Myr mass= 1211.28369852 MSun rvir= 3.23416220644 parsec
# Evolved to t= 9.6234656752 Myr 9.62352023022 Myr mass= 1211.28357617 MSun rvir= 3.23416192409 parsec
# Evolved to t= 9.62346851516 Myr 9.62352023022 Myr mass= 1211.28352253 MSun rvir= 3.23416180031 parsec
# Evolved to t= 9.62346976036 Myr 9.62352023022 Myr mass= 1211.28349901 MSun rvir= 3.23416174603 parsec
# Evolved to t= 9.62347030634 Myr 9.62352023022 Myr mass= 1211.2834887 MSun rvir= 3.23416172224 parsec
# Evolved to t= 9.62347054573 Myr 9.62352023022 Myr mass= 1211.28348418 MSun rvir= 3.2341617118 parsec
# Evolved to t= 9.94346980529 Myr 9.94365314669 Myr mass= 1204.85068662 MSun rvir= 3.42911310346 parsec
# Evolved to t= 9.94347009624 Myr 9.94365314669 Myr mass= 1204.85067941 MSun rvir= 3.42911309341 parsec
# Evolved to t= 9.94347021671 Myr 9.94365314669 Myr mass= 1204.85067642 MSun rvir= 3.42911308925 parsec
# Evolved to t= 9.94347026658 Myr 9.94365314669 Myr mass= 1204.85067518 MSun rvir= 3.42911308753 parsec
# Evolved to t= 9.94347028723 Myr 9.94365314669 Myr mass= 1204.85067467 MSun rvir= 3.42911308681 parsec
# Evolved to t= 9.94347029578 Myr 9.94365314669 Myr mass= 1204.85067446 MSun rvir= 3.42911308652 parsec
# Evolved to t= 9.94347029932 Myr 9.94365314669 Myr mass= 1204.85067437 MSun rvir= 3.4291130864 parsec
# Evolved to t= 9.94347030079 Myr 9.94365314669 Myr mass= 1204.85067433 MSun rvir= 3.42911308634 parsec
# Evolved to t= 9.94347030179 Myr 9.94365314669 Myr mass= 1204.85067431 MSun rvir= 3.42911308631 parsec
# Evolved to t= 9.94347030279 Myr 9.94365314669 Myr mass= 1204.85067429 MSun rvir= 3.42911308628 parsec
# Evolved to t= 10.0450604451 Myr 10.0459450661 Myr mass= 1202.13034971 MSun rvir= 3.49598311571 parsec

# %% [markdown]
# You have performed a small experiment in which a population of stars was evolved from zero-age to an age of 10 Myr.
# The stars were selected randomly from a Salpeter mass function, and distributed in a virialized Plummer sphere with a characteristic (Plummer) radius of 1 pc.
#
# Assignments and questions:
# ---------------
#
# ### Question 1:
# You have plotted the Hertzsprung-Russel diagram and the x-y projection of the cluster before and after the simulation. Describe the differences.
#
# ### Assignment 1:
# Rerun the calculation, but store the time and the virial radius in arrays. Make a plot of the virial radius as a function of time.
#
# ### Question 2:
# Why is the cluster expanding?
#
# ### Question 3:
# Why does it take a while before the cluster starts expanding?
#
# ### Question 4:
# The virial radius does not expand monotonously. Why is that?
#
# ### Assignment 2:
# Rerun the calculation without stellar evolution and quantify the difference in which the cluster expands with and without taking stellar evolution into account.
# When rerunning, make sure that you are using the same initial random seed for generating the initial mass function as well as for assigning the stellar positions and velocities.
#
# Can you explain explain the difference between the simulation with- and the one without stellar evolution?
#
# ### Question 5:
# In a previous assignment you have been checking binary formation.
# What will happen here if you would continue the run until the first binary forms?
#
# ### Assignment 6:
# Add diagnostic checking for energy conservation to the code.
# Make sure to check the energy conservation for stellar evolution and stellar dynamics separately.
#
# ### Question 6:
# Make a plot of the total, the potential and the kinetic energy of the N-body system as a function of time.
#
# To what degree is the total energy conserved?
# Is the amount of energy conservation sufficient to warrant a scientifically valid result, and if so, why is this the case?
#
# ### Assignment 7:
# Replace the event-driven approach from the script and replace is with a simple time stepping in which you step-over from one code to the other every million years.
#
# Now check the evolution of the virial radius and the energy conservation of the code again, and discuss the difference with the original event-driven approach.

# %% [markdown]
# ### Question 1
# Before evolution, the stars are mostly main sequence stars. After evolution, high mass stars have exit the main sequence, while low mass stars evolve slower and many stay at the same position on the H-R diagram. In the x-y field, stars are more separated in space after evolution. All stars have got slower velocity.

# %% [markdown]
# ### Assignment 1

# %%
n_stars = 100
alpha_IMF = -2.35

from amuse.lab import new_powerlaw_mass_distribution
m_stars = new_powerlaw_mass_distribution(n_stars, 
                                         10.0|units.MSun, 
                                         100.0|units.MSun, 
                                         alpha_IMF)

r_cluster = 1.0 | units.parsec
from amuse.units import nbody_system
converter=nbody_system.nbody_to_si(m_stars.sum(), r_cluster)
from amuse.ic.plummer import new_plummer_model
stars=new_plummer_model(n_stars, convert_nbody=converter)
stars.mass = m_stars
stars.scale_to_standard(converter)


stellar = SeBa()
stellar.particles.add_particles(stars)

gravity = ph4(converter)
gravity.particles.add_particles(stars)
ch_s2g = stellar.particles.new_channel_to(gravity.particles)
ch_g2l = gravity.particles.new_channel_to(stars)
ch_s2l = stellar.particles.new_channel_to(stars)
ch_s2l.copy()


time_list = []
rvir_list = []

end_time = 10.0 | units.Myr
model_time = 0 | units.Myr
while(model_time<end_time):
    dt = stellar.particles.time_step.min()
    model_time += dt
    stellar.evolve_model(model_time)
    ch_s2g.copy()
    ch_s2l.copy()
    gravity.evolve_model(model_time)
    ch_g2l.copy()
    
    time_list.append(stellar.model_time.value_in(units.Myr))
    rvir_list.append(stars.virial_radius().value_in(units.pc))
    
plot_snapshot(stars)
stellar.stop()
gravity.stop()

time_list = time_list | units.Myr
rvir_list = rvir_list | units.pc

# %%
fig, ax = pyplot.subplots(1, 1, figsize=(5, 3))

ax.plot(time_list.value_in(units.Myr), rvir_list.value_in(units.pc))
ax.set_xlabel("Time [Myr]")
ax.set_ylabel("Virial Radius [pc]")
pyplot.show()

# %% [markdown]
# ### Question 2
# Because the

# %% [markdown]
# ### Question 3
# It takes time for the most massive stars to evolve out of the main sequence and lose mass.

# %% [markdown]
# ### Question 4
# There should be some fluctuations？

# %% [markdown]
# ### Assignment 2

# %%
n_stars = 100
alpha_IMF = -2.35

m_stars = new_powerlaw_mass_distribution(n_stars, 
                                         10.0|units.MSun, 
                                         100.0|units.MSun, 
                                         alpha_IMF)

r_cluster = 1.0 | units.parsec

converter=nbody_system.nbody_to_si(m_stars.sum(), r_cluster)

numpy.random.seed(1234)
stars_evo=new_plummer_model(n_stars, convert_nbody=converter)
numpy.random.seed(1234)
stars_sta=new_plummer_model(n_stars, convert_nbody=converter)
stars_evo.mass = m_stars
stars_sta.mass = m_stars
stars_evo.scale_to_standard(converter)
stars_sta.scale_to_standard(converter)


stellar = SeBa()
stellar.particles.add_particles(stars_evo)

gravity_evo = ph4(converter)
gravity_sta = ph4(converter)
gravity_evo.particles.add_particles(stars_evo)
gravity_sta.particles.add_particles(stars_sta)

ch_s2g = stellar.particles.new_channel_to(gravity_evo.particles)
ch_g2l = gravity_evo.particles.new_channel_to(stars_evo)
ch_s2l = stellar.particles.new_channel_to(stars_evo)
ch_s2l.copy()

ch_sta = gravity_sta.particles.new_channel_to(stars_sta)
ch_sta.copy()


time_evo_list = []
rvir_evo_list = []
time_sta_list = []
rvir_sta_list = []

end_time = 10.0 | units.Myr
model_time = 0 | units.Myr

while(model_time<end_time):
    dt = stellar.particles.time_step.min()
    model_time += dt
    stellar.evolve_model(model_time)
    ch_s2g.copy()
    ch_s2l.copy()
    gravity_evo.evolve_model(model_time)
    ch_g2l.copy()
    
    time_evo_list.append(stellar.model_time.value_in(units.Myr))
    rvir_evo_list.append(stars_evo.virial_radius().value_in(units.pc))
    
times = numpy.arange(0, 10, 0.001) | units.Myr
for time in times:
    gravity_sta.evolve_model(time)
    ch_sta.copy()
    
    time_sta_list.append(time.value_in(units.Myr))
    rvir_sta_list.append(stars_sta.virial_radius().value_in(units.pc))
    

stellar.stop()
gravity_evo.stop()
gravity_sta.stop()

time_evo_list = time_evo_list | units.Myr
rvir_evo_list = rvir_evo_list | units.pc
time_sta_list = time_sta_list | units.Myr
rvir_sta_list = rvir_sta_list | units.pc

# %%
fig, ax = pyplot.subplots(1, 1, figsize=(5, 3))

ax.plot(time_evo_list.value_in(units.Myr), rvir_evo_list.value_in(units.pc), label='Evolving Stars')
ax.plot(time_sta_list.value_in(units.Myr), rvir_sta_list.value_in(units.pc), label='Static Stars')
ax.set_xlabel("Time [Myr]")
ax.set_ylabel("Virial Radius [pc]")
pyplot.legend()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'ScalarQuantity'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6b435c442c58> in <module>
#       1 fig, ax = pyplot.subplots(1, 1, figsize=(5, 3))
#       2
# ----> 3 ax.plot(time_evo_list.value_in(units.Myr), rvir_evo_list.value_in(units.pc), label='Evolving Stars')
#       4 ax.plot(time_sta_list.value_in(units.Myr), rvir_sta_list.value_in(units.pc), label='Static Stars')
#       5 ax.set_xlabel("Time [Myr]")
#
# /usr/lib64/python3.10/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1635         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636         for line in lines:
# -> 1637             self.add_line(line)
#    1638         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1639         return lines
#
# /usr/lib64/python3.10/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    2286             line.set_clip_path(self.patch)
#    2287
# -> 2288         self._update_line_limits(line)
#    2289         if not line.get_label():
#    2290             line.set_label(f'_child{len(self._children)}')
#
# /usr/lib64/python3.10/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    2309         Figures out the data limit of the given line, updating self.dataLim.
#    2310         """
# -> 2311         path = line.get_path()
#    2312         if path.vertices.size == 0:
#    2313             return
#
# /usr/lib64/python3.10/site-packages/matplotlib/lines.py in get_path(self)
#     997         """Return the `~matplotlib.path.Path` associated with this line."""
#     998         if self._invalidy or self._invalidx:
# --> 999             self.recache()
#    1000         return self._path
#    1001
#
# /usr/lib64/python3.10/site-packages/matplotlib/lines.py in recache(self, always)
#     650         if always or self._invalidx:
#     651             xconv = self.convert_xunits(self._xorig)
# --> 652             x = _to_unmasked_float_array(xconv).ravel()
#     653         else:
#     654             x = self._x
#
# /usr/lib64/python3.10/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1296         return np.ma.asarray(x, float).filled(np.nan)
#    1297     else:
# -> 1298         return np.asarray(x, float)
#    1299
#    1300
#
# ValueError: setting an array element with a sequence.
